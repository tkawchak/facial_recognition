# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img, img_to_array, load_img
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
# an object to randomly transform photo data to give
# more training examples
datagen = ImageDataGenerator(
    rotation_range=20,  # rotation range within which to rotate pictures
    width_shift_range=0.2,  # range of horizontal translation
    height_shift_range=0.2,  # range of vertical translation
    rescale = 1./255,  # scales the images to be suitable for training
    shear_range=0,  # shear transformation, i don't want this for images
    zoom_range=0.2,  # zoom in and out
    horizontal_flip=True,  # flip some images horizontally
    fill_mode='reflect')  # reflect pixel values in order to fill images

# path to original training images with face - before transformations
face_image_path = './data/face_images/train_originals/face/'
# path to original training images with no face - before transformations
none_image_path = './data/face_images/train_originals/none/'

# gather the names of the images in the above paths
face_image_names = glob.glob(face_image_path + '*.jpg')
none_image_names = glob.glob(none_image_path + '*.jpg')

# number of batches to output
# the total number of images will be the total number
# of batches multiplied by the batch size
num_batches = 100
batch_size = 100

# output directories for image generation
output_dir_face = './data/face_images/train/face'
output_dir_none = './data/face_images/train/none'

# %%
# generate face training data

# load all images and add them to an array
# that contains all images
x = []
for image_name in face_image_names:
    img = load_img(image_name)
    img_array = img_to_array(img)
    x.append(img_array)
x = np.array(x)

# i will keep track of the number of batches that we have
# processed so far.  We check its value at the end of the loop
# otherwise, this would keep producing images indefinitely
i = 0
# this will automatically write data to the specified output directory
for batch in datagen.flow(x, batch_size=batch_size, shuffle=True,
                          save_to_dir=output_dir_face,
                          save_prefix='train', 
                          save_format='jpeg'):
    i += 1
    print('face image generator batch: ' + str(i))
    if i > num_batches:
        break
        

# generate non-face training data
# this uses the same method described above for
# the face training data
        
x = []
for image_name in none_image_names:
    img = load_img(image_name)
    img_array = img_to_array(img)
    x.append(img_array)
x = np.array(x)

i = 0
for batch in datagen.flow(x, batch_size=batch_size, shuffle=True,
                          save_to_dir=output_dir_none,
                          save_prefix='train',
                          save_format='jpeg'):
    i += 1
    print('non-face image generator batch: ' + str(i))
    if i > num_batches:
        break
# Out:
# face image generator batch: 1
# face image generator batch: 2
# face image generator batch: 3
# face image generator batch: 4
# face image generator batch: 5
# face image generator batch: 6
# face image generator batch: 7
# face image generator batch: 8
# face image generator batch: 9
# face image generator batch: 10
# face image generator batch: 11
# face image generator batch: 12
# face image generator batch: 13
# face image generator batch: 14
# face image generator batch: 15
# face image generator batch: 16
# face image generator batch: 17
# face image generator batch: 18
# face image generator batch: 19
# face image generator batch: 20
# face image generator batch: 21
# face image generator batch: 22
# face image generator batch: 23
# face image generator batch: 24
# face image generator batch: 25
# face image generator batch: 26
# face image generator batch: 27
# face image generator batch: 28
# face image generator batch: 29
# face image generator batch: 30
# face image generator batch: 31
# face image generator batch: 32
# face image generator batch: 33
# face image generator batch: 34
# face image generator batch: 35
# face image generator batch: 36
# face image generator batch: 37
# face image generator batch: 38
# face image generator batch: 39
# face image generator batch: 40
# face image generator batch: 41
# face image generator batch: 42
# face image generator batch: 43
# face image generator batch: 44
# face image generator batch: 45
# face image generator batch: 46
# face image generator batch: 47
# face image generator batch: 48
# face image generator batch: 49
# face image generator batch: 50
# face image generator batch: 51
# face image generator batch: 52
# face image generator batch: 53
# face image generator batch: 54
# face image generator batch: 55
# face image generator batch: 56
# face image generator batch: 57
# face image generator batch: 58
# face image generator batch: 59
# face image generator batch: 60
# face image generator batch: 61
# face image generator batch: 62
# face image generator batch: 63
# face image generator batch: 64
# face image generator batch: 65
# face image generator batch: 66
# face image generator batch: 67
# face image generator batch: 68
# face image generator batch: 69
# face image generator batch: 70
# face image generator batch: 71
# face image generator batch: 72
# face image generator batch: 73
# face image generator batch: 74
# face image generator batch: 75
# face image generator batch: 76
# face image generator batch: 77
# face image generator batch: 78
# face image generator batch: 79
# face image generator batch: 80
# face image generator batch: 81
# face image generator batch: 82
# face image generator batch: 83
# face image generator batch: 84
# face image generator batch: 85
# face image generator batch: 86
# face image generator batch: 87
# face image generator batch: 88
# face image generator batch: 89
# face image generator batch: 90
# face image generator batch: 91
# face image generator batch: 92
# face image generator batch: 93
# face image generator batch: 94
# face image generator batch: 95
# face image generator batch: 96
# face image generator batch: 97
# face image generator batch: 98
# face image generator batch: 99
# face image generator batch: 100
# face image generator batch: 101
# non-face image generator batch: 1
# non-face image generator batch: 2
# non-face image generator batch: 3
# non-face image generator batch: 4
# non-face image generator batch: 5
# non-face image generator batch: 6
# non-face image generator batch: 7
# non-face image generator batch: 8
# non-face image generator batch: 9
# non-face image generator batch: 10
# non-face image generator batch: 11
# non-face image generator batch: 12
# non-face image generator batch: 13
# non-face image generator batch: 14
# non-face image generator batch: 15
# non-face image generator batch: 16
# non-face image generator batch: 17
# non-face image generator batch: 18
# non-face image generator batch: 19
# non-face image generator batch: 20
# non-face image generator batch: 21
# non-face image generator batch: 22
# non-face image generator batch: 23
# non-face image generator batch: 24
# non-face image generator batch: 25
# non-face image generator batch: 26
# non-face image generator batch: 27
# non-face image generator batch: 28
# non-face image generator batch: 29
# non-face image generator batch: 30
# non-face image generator batch: 31
# non-face image generator batch: 32
# non-face image generator batch: 33
# non-face image generator batch: 34
# non-face image generator batch: 35
# non-face image generator batch: 36
# non-face image generator batch: 37
# non-face image generator batch: 38
# non-face image generator batch: 39
# non-face image generator batch: 40
# non-face image generator batch: 41
# non-face image generator batch: 42
# non-face image generator batch: 43
# non-face image generator batch: 44
# non-face image generator batch: 45
# non-face image generator batch: 46
# non-face image generator batch: 47
# non-face image generator batch: 48
# non-face image generator batch: 49
# non-face image generator batch: 50
# non-face image generator batch: 51
# non-face image generator batch: 52
# non-face image generator batch: 53
# non-face image generator batch: 54
# non-face image generator batch: 55
# non-face image generator batch: 56
# non-face image generator batch: 57
# non-face image generator batch: 58
# non-face image generator batch: 59
# non-face image generator batch: 60
# non-face image generator batch: 61
# non-face image generator batch: 62
# non-face image generator batch: 63
# non-face image generator batch: 64
# non-face image generator batch: 65
# non-face image generator batch: 66
# non-face image generator batch: 67
# non-face image generator batch: 68
# non-face image generator batch: 69
# non-face image generator batch: 70
# non-face image generator batch: 71
# non-face image generator batch: 72
# non-face image generator batch: 73
# non-face image generator batch: 74
# non-face image generator batch: 75
# non-face image generator batch: 76
# non-face image generator batch: 77
# non-face image generator batch: 78
# non-face image generator batch: 79
# non-face image generator batch: 80
# non-face image generator batch: 81
# non-face image generator batch: 82
# non-face image generator batch: 83
# non-face image generator batch: 84
# non-face image generator batch: 85
# non-face image generator batch: 86
# non-face image generator batch: 87
# non-face image generator batch: 88
# non-face image generator batch: 89
# non-face image generator batch: 90
# non-face image generator batch: 91
# non-face image generator batch: 92
# non-face image generator batch: 93
# non-face image generator batch: 94
# non-face image generator batch: 95
# non-face image generator batch: 96
# non-face image generator batch: 97
# non-face image generator batch: 98
# non-face image generator batch: 99
# non-face image generator batch: 100
# non-face image generator batch: 101
